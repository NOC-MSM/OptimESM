# %% [markdown]
# ## **EC-Earth Meridional ovErTurning ciRculation diagnostIC (METRIC) Configurations**
#
# #### Created By:
#
# Ollie Tooth (oliver.tooth@noc.ac.uk)

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
xr.open_dataset("/g100/home/userexternal/otooth00/OptimESM/data/CINECA/SMHI/EC-Earth_Ofx/mesh_mask_nemo.Ec3.2_O1L75.nc")
# Out:
# <xarray.Dataset> Size: 425MB
# Dimensions:       (y: 292, x: 362, z: 75, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/44)
#     nav_lon       (y, x) float32 423kB ...
#     nav_lat       (y, x) float32 423kB ...
#     nav_lev       (z) float32 300B ...
#     time_counter  (t) float64 8B ...
#     tmask         (t, z, y, x) int8 8MB ...
#     umask         (t, z, y, x) int8 8MB ...
#     ...            ...
#     gdepv         (t, z, y, x) float32 32MB ...
#     gdepw_0       (t, z, y, x) float32 32MB ...
#     gdept_1d      (t, z) float64 600B ...
#     gdepw_1d      (t, z) float64 600B ...
#     e3t_1d        (t, z) float64 600B ...
#     e3w_1d        (t, z) float64 600B ...
# Attributes:
#     file_name:  mesh_mask.nc
#     TimeStamp:  23/02/2016 15:55:35 +0100

# %%
fpath="/g100_store/DRES_OptimESM/ESGF/prepub/smhi/20240622/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-ESM-1/esm-hist/r5i1p1f1/Omon/thetao/gn/v20240622/thetao_Omon_EC-Earth3-ESM-1_esm-hist_r5i1p1f1_gn_185001-185012.nc"

ds_thetao = xr.open_dataset(fpath)
ds_thetao
# Out:
# <xarray.Dataset> Size: 389MB
# Dimensions:             (time: 12, bnds: 2, lev: 75, j: 292, i: 362, vertices: 4)
# Coordinates:
#   * time                (time) datetime64[ns] 96B 1850-01-16T12:00:00 ... 185...
#   * lev                 (lev) float64 600B 0.5058 1.556 ... 5.698e+03 5.902e+03
#   * j                   (j) int32 1kB 1 2 3 4 5 6 7 ... 287 288 289 290 291 292
#   * i                   (i) int32 1kB 1 2 3 4 5 6 7 ... 357 358 359 360 361 362
#     latitude            (j, i) float64 846kB ...
#     longitude           (j, i) float64 846kB ...
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (time, bnds) datetime64[ns] 192B ...
#     lev_bnds            (lev, bnds) float64 1kB ...
#     vertices_latitude   (j, i, vertices) float64 3MB ...
#     vertices_longitude  (j, i, vertices) float64 3MB ...
#     thetao              (time, lev, j, i) float32 381MB ...
# Attributes: (12/49)
#     Conventions:                        CF-1.7 CMIP-6.2
#     activity_id:                        CMIP
#     branch_method:                      standard
#     branch_time_in_child:               0.0
#     branch_time_in_parent:              29219.0
#     comment:                            This experiment was done as part of O...
#     ...                                 ...
#     title:                              EC-Earth3-ESM-1 output prepared for C...
#     tracking_id:                        hdl:21.14100/f70cea4f-a94d-42e9-bb8d-...
#     variable_id:                        thetao
#     variant_label:                      r5i1p1f1
#     license:                            CMIP6 model data produced by EC-Earth...
#     cmor_version:                       3.8.0

# %%
i1 = 206
i2 = 280
j1 = 189
j2 = 189

plt.pcolormesh(ds_thetao.longitude, ds_thetao.latitude, ds_thetao.thetao.isel(time=0, lev=0))
plt.plot(ds_thetao.longitude.isel(i=slice(i1, i2), j=j1), ds_thetao.latitude.isel(i=slice(i1, i2), j=j1), color='coral')

plt.xlim([-85+360, 360])
plt.ylim([5, 35])

# %%
fc_minlon = -81.0 + 360
fc_maxlon = -77.5 + 360
wbw_maxlon = -76.1 + 360
int_maxlon = -10 + 360

print(fc_minlon, fc_maxlon, wbw_maxlon, int_maxlon)

# %%
ds_thetao.longitude.isel(i=[i1, i2], j=j1).values

# %%
ds_thetao.latitude.isel(i=slice(i1, i2), j=j1).mean()

# %% [markdown]
# ### **Define NEMO t/u/v masks**

# %%
# Example T-grid file:
fpath="/g100_store/DRES_OptimESM/ESGF/prepub/smhi/20240622/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-ESM-1/esm-hist/r5i1p1f1/Omon/thetao/gn/v20240622/thetao_Omon_EC-Earth3-ESM-1_esm-hist_r5i1p1f1_gn_185001-185012.nc"
ds_thetao = xr.open_dataset(fpath)

# Example U-grid file:
fpath="/g100_store/DRES_OptimESM/ESGF/prepub/smhi/20240622/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-ESM-1/esm-hist/r5i1p1f1/Omon/uo/gn/v20240622/uo_Omon_EC-Earth3-ESM-1_esm-hist_r5i1p1f1_gn_185001-185012.nc"
ds_uo = xr.open_dataset(fpath)

# Example V-grid file:
fpath="/g100_store/DRES_OptimESM/ESGF/prepub/smhi/20240622/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-ESM-1/esm-hist/r5i1p1f1/Omon/vo/gn/v20240622/vo_Omon_EC-Earth3-ESM-1_esm-hist_r5i1p1f1_gn_185001-185012.nc"
ds_vo = xr.open_dataset(fpath)

# %%
t_mask = ~np.isnan(ds_thetao["thetao"].isel(time=0))
u_mask = ~np.isnan(ds_uo["uo"].isel(time=0))
v_mask = ~np.isnan(ds_vo["vo"].isel(time=0))

# %%
i1 = 206
i2 = 280
j1 = 189
j2 = 189

t_mask.isel(i=slice(i1, i2), j=j1).plot()

# %%
# Use EC-Earth T-grid file as template DataSet:

ds_thetao = ds_thetao.drop_vars(ds_thetao.data_vars)
ds_thetao["tmask"] = t_mask
ds_thetao["umask"] = u_mask
ds_thetao["vmask"] = v_mask

# Write masks to mesh_mask netCDF file:
out_fpath="/g100/home/userexternal/otooth00/OptimESM/data/CINECA/SMHI/EC-Earth_Ofx/mesh_mask_Ofx_EC-Earth.nc"
ds_thetao.to_netcdf(out_fpath)

# %%
xr.open_dataset(out_fpath)

# %% [markdown]
# ### **Testing METRIC Outputs**

# %%
fpath="/g100_work/optim_IAC/research/noc/otooth/OptimESM_WP4/data/SMHI/EC-Earth3-ESM-1_esm-hist_r5i1p1f1_1850-01-2014-12_natl_meridional_transports_at_26N.nc"

ds_test = xr.open_dataset(fpath)
ds_test

# %%
ds_test.v.mean(dim="time").plot()
plt.ylim([6000, 0])
plt.axvline(x=282.5)

# %%
ds_test.moc_rapid.plot()

# %%
ds_test.moc_rapid.plot()
